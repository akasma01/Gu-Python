# %%
import pandas as pd

# %%
data = pd.read_csv("Downloads/train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print(data.shape)
# Out:
# (891, 12)

# %%
data[["PassengerId","Name"]]
# Out:
#      PassengerId                                               Name
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
r,c=data.shape
print(r)
print(c)
# Out:
# 891
# 12

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data[5:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(data.Name)
#data[["Name"]]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Ticket'].min()
# Out:
# '110152'

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
a = [1, 7, 2]
myvar = pd.Series(a)

# %%
myvar
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
myvar = pd.Series(a, index = ["x", "y", "z"])

# %%
myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
df = {
   "calories": [500, 6000, 790],
   "duration": [40, 75, 65]
}

# %%
df
# Out:
# {'calories': [500, 6000, 790], 'duration': [40, 75, 65]}

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#    calories  duration
# 0       500        40
# 1      6000        75
# 2       790        65

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Drop Null values

# %%
data1 = data.dropna()

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# Replace null values with mean

# %%
#print(data1.to_string())

# %%
data["Age"].fillna(data["Age"].mean(), inplace=True )

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data["Age"]
# Out:
# 1      38.0
# 3      35.0
# 6      54.0
# 10      4.0
# 11     58.0
#        ...
# 871    47.0
# 872    33.0
# 879    56.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 202, dtype: float64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.8.2

# %%
import matplotlib.pyplot as plt

# %%
x=data['PassengerId']
y=data["Age"]
plt.bar(x,y,label="Age",color="green")
plt.xlabel("Passenger ID")
plt.ylabel("Passenger Age")
plt.title("Passenger Information")
plt.legend()
plt.show()

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
x=data['Age']
y=data["Fare"]
plt.bar(x,y,label="Age",color="green")
plt.xlabel("Passenger ID")
plt.ylabel("Passenger Age")
plt.title("Passenger Information")
plt.legend()
plt.show()

# %%
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.grid()
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import numpy as np
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.grid()
plt.title("hello")
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y, color="red")
# Out:
# <BarContainer object of 4 artists>

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,color="red")

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,color="green")

plt.show()

# %%
a = np.random.normal(100,10,200)

# %%
plt.hist(a)
# Out:
# (array([ 2.,  7., 19., 38., 35., 42., 32., 14.,  6.,  5.]),
#  array([ 76.70939426,  81.73908086,  86.76876746,  91.79845406,
#          96.82814066, 101.85782725, 106.88751385, 111.91720045,
#         116.94688705, 121.97657364, 127.00626024]),
#  <BarContainer object of 10 artists>)

# %%
y = np.array([35, 25, 25, 10])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels,startangle = 90)
plt.legend()
plt.show()

# %%
y = np.array([75, 5, 7, 13])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0.2, 0, 0]


plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
#plt.legend()
plt.show()

# %%
plt.boxplot(data["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2504da80710>,
#   <matplotlib.lines.Line2D at 0x2504da814d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2504da83290>,
#   <matplotlib.lines.Line2D at 0x2504da80e50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2504dafdc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2504dc2d710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2504dc2f810>],
#  'means': []}

# %%
plt.bar(data["Age"], data["Pclass"])
# Out:
# <BarContainer object of 202 artists>

# %%
plt.pie(data["Survived"],)
# Out:
# ([<matplotlib.patches.Wedge at 0x2505133c250>,
#   <matplotlib.patches.Wedge at 0x2504e43b890>,
#   <matplotlib.patches.Wedge at 0x2505133f110>,
#   <matplotlib.patches.Wedge at 0x2505133d710>,
#   <matplotlib.patches.Wedge at 0x250513349d0>,
#   <matplotlib.patches.Wedge at 0x25051334e50>,
#   <matplotlib.patches.Wedge at 0x250513356d0>,
#   <matplotlib.patches.Wedge at 0x25051335450>,
#   <matplotlib.patches.Wedge at 0x25050f71890>,
#   <matplotlib.patches.Wedge at 0x25051334110>,
#   <matplotlib.patches.Wedge at 0x25051302a50>,
#   <matplotlib.patches.Wedge at 0x25051300b90>,
#   <matplotlib.patches.Wedge at 0x25051302790>,
#   <matplotlib.patches.Wedge at 0x25051300a10>,
#   <matplotlib.patches.Wedge at 0x25051318d50>,
#   <matplotlib.patches.Wedge at 0x25051319950>,
#   <matplotlib.patches.Wedge at 0x2505131bbd0>,
#   <matplotlib.patches.Wedge at 0x25051318750>,
#   <matplotlib.patches.Wedge at 0x25051329e90>,
#   <matplotlib.patches.Wedge at 0x2505132a910>,
#   <matplotlib.patches.Wedge at 0x25051322010>,
#   <matplotlib.patches.Wedge at 0x250513208d0>,
#   <matplotlib.patches.Wedge at 0x25050e56710>,
#   <matplotlib.patches.Wedge at 0x250512a6550>,
#   <matplotlib.patches.Wedge at 0x250512a6510>,
#   <matplotlib.patches.Wedge at 0x250512a7bd0>,
#   <matplotlib.patches.Wedge at 0x2504c72ac90>,
#   <matplotlib.patches.Wedge at 0x250512e3250>,
#   <matplotlib.patches.Wedge at 0x250512e32d0>,
#   <matplotlib.patches.Wedge at 0x250512e1cd0>,
#   <matplotlib.patches.Wedge at 0x250512a08d0>,
#   <matplotlib.patches.Wedge at 0x250512a0fd0>,
#   <matplotlib.patches.Wedge at 0x250512a0090>,
#   <matplotlib.patches.Wedge at 0x250512a2b90>,
#   <matplotlib.patches.Wedge at 0x250510d7e50>,
#   <matplotlib.patches.Wedge at 0x250512f4150>,
#   <matplotlib.patches.Wedge at 0x250512c3550>,
#   <matplotlib.patches.Wedge at 0x2504debea50>,
#   <matplotlib.patches.Wedge at 0x250512de6d0>,
#   <matplotlib.patches.Wedge at 0x250512df810>,
#   <matplotlib.patches.Wedge at 0x250512fa390>,
#   <matplotlib.patches.Wedge at 0x25051142110>,
#   <matplotlib.patches.Wedge at 0x250512f3e90>,
#   <matplotlib.patches.Wedge at 0x250512da010>,
#   <matplotlib.patches.Wedge at 0x250512da790>,
#   <matplotlib.patches.Wedge at 0x2505137d510>,
#   <matplotlib.patches.Wedge at 0x2505137db90>,
#   <matplotlib.patches.Wedge at 0x2505137fc50>,
#   <matplotlib.patches.Wedge at 0x25051178b10>,
#   <matplotlib.patches.Wedge at 0x25051179a50>,
#   <matplotlib.patches.Wedge at 0x2505117a8d0>,
#   <matplotlib.patches.Wedge at 0x2505117b6d0>,
#   <matplotlib.patches.Wedge at 0x250511844d0>,
#   <matplotlib.patches.Wedge at 0x25051185390>,
#   <matplotlib.patches.Wedge at 0x25051186290>,
#   <matplotlib.patches.Wedge at 0x25051187090>,
#   <matplotlib.patches.Wedge at 0x25051187f10>,
#   <matplotlib.patches.Wedge at 0x25051198d10>,
#   <matplotlib.patches.Wedge at 0x25051199ad0>,
#   <matplotlib.patches.Wedge at 0x2505119a9d0>,
#   <matplotlib.patches.Wedge at 0x2505119b890>,
#   <matplotlib.patches.Wedge at 0x250511a8690>,
#   <matplotlib.patches.Wedge at 0x250511a9490>,
#   <matplotlib.patches.Wedge at 0x250511aa2d0>,
#   <matplotlib.patches.Wedge at 0x250511ab290>,
#   <matplotlib.patches.Wedge at 0x250511b41d0>,
#   <matplotlib.patches.Wedge at 0x250511b50d0>,
#   <matplotlib.patches.Wedge at 0x250511b60d0>,
#   <matplotlib.patches.Wedge at 0x250511b6f50>,
#   <matplotlib.patches.Wedge at 0x250511b7d50>,
#   <matplotlib.patches.Wedge at 0x250511c4c50>,
#   <matplotlib.patches.Wedge at 0x250511c5bd0>,
#   <matplotlib.patches.Wedge at 0x250511c6a10>,
#   <matplotlib.patches.Wedge at 0x250511c7890>,
#   <matplotlib.patches.Wedge at 0x250511d4750>,
#   <matplotlib.patches.Wedge at 0x250511d5610>,
#   <matplotlib.patches.Wedge at 0x250511d6490>,
#   <matplotlib.patches.Wedge at 0x250511d7310>,
#   <matplotlib.patches.Wedge at 0x250511e4150>,
#   <matplotlib.patches.Wedge at 0x250474ab950>,
#   <matplotlib.patches.Wedge at 0x250512bac10>,
#   <matplotlib.patches.Wedge at 0x250512b8f90>,
#   <matplotlib.patches.Wedge at 0x250512ecad0>,
#   <matplotlib.patches.Wedge at 0x250512ec3d0>,
#   <matplotlib.patches.Wedge at 0x250512b2050>,
#   <matplotlib.patches.Wedge at 0x250512f0d10>,
#   <matplotlib.patches.Wedge at 0x250512f00d0>,
#   <matplotlib.patches.Wedge at 0x250512f2a50>,
#   <matplotlib.patches.Wedge at 0x250512f4b10>,
#   <matplotlib.patches.Wedge at 0x250512f58d0>,
#   <matplotlib.patches.Wedge at 0x250512f40d0>,
#   <matplotlib.patches.Wedge at 0x250512fb1d0>,
#   <matplotlib.patches.Wedge at 0x250512f8410>,
#   <matplotlib.patches.Wedge at 0x250512f9650>,
#   <matplotlib.patches.Wedge at 0x25051141790>,
#   <matplotlib.patches.Wedge at 0x25051142e50>,
#   <matplotlib.patches.Wedge at 0x25050bf5c10>,
#   <matplotlib.patches.Wedge at 0x25050bf5190>,
#   <matplotlib.patches.Wedge at 0x25050bf6650>,
#   <matplotlib.patches.Wedge at 0x25050c17550>,
#   <matplotlib.patches.Wedge at 0x25050c14b10>,
#   <matplotlib.patches.Wedge at 0x25050c16790>,
#   <matplotlib.patches.Wedge at 0x25050c17f90>,
#   <matplotlib.patches.Wedge at 0x25050c342d0>,
#   <matplotlib.patches.Wedge at 0x25050c35d10>,
#   <matplotlib.patches.Wedge at 0x25050c37610>,
#   <matplotlib.patches.Wedge at 0x25050bc9890>,
#   <matplotlib.patches.Wedge at 0x25050bc9750>,
#   <matplotlib.patches.Wedge at 0x25050bcb390>,
#   <matplotlib.patches.Wedge at 0x25050a3fd90>,
#   <matplotlib.patches.Wedge at 0x25050a3cdd0>,
#   <matplotlib.patches.Wedge at 0x25050a3ea10>,
#   <matplotlib.patches.Wedge at 0x25050c5d410>,
#   <matplotlib.patches.Wedge at 0x25050c5c050>,
#   <matplotlib.patches.Wedge at 0x25050c5df90>,
#   <matplotlib.patches.Wedge at 0x25050c5fb10>,
#   <matplotlib.patches.Wedge at 0x25050c4a490>,
#   <matplotlib.patches.Wedge at 0x25050c49c50>,
#   <matplotlib.patches.Wedge at 0x25050c4b2d0>,
#   <matplotlib.patches.Wedge at 0x25050a5ee50>,
#   <matplotlib.patches.Wedge at 0x25050a5cdd0>,
#   <matplotlib.patches.Wedge at 0x25050a5e710>,
#   <matplotlib.patches.Wedge at 0x25050a5eb90>,
#   <matplotlib.patches.Wedge at 0x25050b94150>,
#   <matplotlib.patches.Wedge at 0x25050b96290>,
#   <matplotlib.patches.Wedge at 0x25050b97910>,
#   <matplotlib.patches.Wedge at 0x25050b69650>,
#   <matplotlib.patches.Wedge at 0x25050b69750>,
#   <matplotlib.patches.Wedge at 0x25050b6b310>,
#   <matplotlib.patches.Wedge at 0x25050b7b290>,
#   <matplotlib.patches.Wedge at 0x25050b78d50>,
#   <matplotlib.patches.Wedge at 0x25050b7a110>,
#   <matplotlib.patches.Wedge at 0x25050a4dc90>,
#   <matplotlib.patches.Wedge at 0x25050a4c7d0>,
#   <matplotlib.patches.Wedge at 0x25050a4df50>,
#   <matplotlib.patches.Wedge at 0x25050a4f910>,
#   <matplotlib.patches.Wedge at 0x25050ba7850>,
#   <matplotlib.patches.Wedge at 0x25050ba5650>,
#   <matplotlib.patches.Wedge at 0x25050ba7410>,
#   <matplotlib.patches.Wedge at 0x25050c055d0>,
#   <matplotlib.patches.Wedge at 0x25050c04e90>,
#   <matplotlib.patches.Wedge at 0x25050c06a50>,
#   <matplotlib.patches.Wedge at 0x250510d9190>,
#   <matplotlib.patches.Wedge at 0x250510dab90>,
#   <matplotlib.patches.Wedge at 0x250510d9750>,
#   <matplotlib.patches.Wedge at 0x250510db010>,
#   <matplotlib.patches.Wedge at 0x2505110bd50>,
#   <matplotlib.patches.Wedge at 0x2505110b290>,
#   <matplotlib.patches.Wedge at 0x250510e5210>,
#   <matplotlib.patches.Wedge at 0x250510e5a10>,
#   <matplotlib.patches.Wedge at 0x250510e6090>,
#   <matplotlib.patches.Wedge at 0x250510e6ad0>,
#   <matplotlib.patches.Wedge at 0x250510fd910>,
#   <matplotlib.patches.Wedge at 0x250510ff590>,
#   <matplotlib.patches.Wedge at 0x25051105ed0>,
#   <matplotlib.patches.Wedge at 0x25051107f50>,
#   <matplotlib.patches.Wedge at 0x25051104810>,
#   <matplotlib.patches.Wedge at 0x250510e8410>,
#   <matplotlib.patches.Wedge at 0x250510eb790>,
#   <matplotlib.patches.Wedge at 0x25051113990>,
#   <matplotlib.patches.Wedge at 0x250512c23d0>,
#   <matplotlib.patches.Wedge at 0x250512c0350>,
#   <matplotlib.patches.Wedge at 0x250512c0fd0>,
#   <matplotlib.patches.Wedge at 0x250510b9110>,
#   <matplotlib.patches.Wedge at 0x250510b9610>,
#   <matplotlib.patches.Wedge at 0x250510ba810>,
#   <matplotlib.patches.Wedge at 0x250510adc90>,
#   <matplotlib.patches.Wedge at 0x250510ac510>,
#   <matplotlib.patches.Wedge at 0x250510aea10>,
#   <matplotlib.patches.Wedge at 0x250510a23d0>,
#   <matplotlib.patches.Wedge at 0x250510a0290>,
#   <matplotlib.patches.Wedge at 0x250510a2190>,
#   <matplotlib.patches.Wedge at 0x250510a2b90>,
#   <matplotlib.patches.Wedge at 0x25051066590>,
#   <matplotlib.patches.Wedge at 0x25051065210>,
#   <matplotlib.patches.Wedge at 0x25051067410>,
#   <matplotlib.patches.Wedge at 0x25051038d90>,
#   <matplotlib.patches.Wedge at 0x25051038a50>,
#   <matplotlib.patches.Wedge at 0x2505103b150>,
#   <matplotlib.patches.Wedge at 0x25051027ed0>,
#   <matplotlib.patches.Wedge at 0x250510247d0>,
#   <matplotlib.patches.Wedge at 0x25051025990>,
#   <matplotlib.patches.Wedge at 0x250510270d0>,
#   <matplotlib.patches.Wedge at 0x2505100ea50>,
#   <matplotlib.patches.Wedge at 0x2505100ced0>,
#   <matplotlib.patches.Wedge at 0x2505100eed0>,
#   <matplotlib.patches.Wedge at 0x25050fd6b50>,
#   <matplotlib.patches.Wedge at 0x25050fd4150>,
#   <matplotlib.patches.Wedge at 0x25050fd61d0>,
#   <matplotlib.patches.Wedge at 0x25050fd4a90>,
#   <matplotlib.patches.Wedge at 0x25050f72450>,
#   <matplotlib.patches.Wedge at 0x25050f710d0>,
#   <matplotlib.patches.Wedge at 0x25050f732d0>,
#   <matplotlib.patches.Wedge at 0x25050f6b290>,
#   <matplotlib.patches.Wedge at 0x25050f683d0>,
#   <matplotlib.patches.Wedge at 0x25050f69b10>,
#   <matplotlib.patches.Wedge at 0x25050f6ba90>,
#   <matplotlib.patches.Wedge at 0x25050f5c390>,
#   <matplotlib.patches.Wedge at 0x25050f5d450>,
#   <matplotlib.patches.Wedge at 0x25050f5f450>,
#   <matplotlib.patches.Wedge at 0x25050f4ea90>,
#   <matplotlib.patches.Wedge at 0x25050f4c710>,
#   <matplotlib.patches.Wedge at 0x25050f4ec10>,
#   <matplotlib.patches.Wedge at 0x25050f3e050>,
#   <matplotlib.patches.Wedge at 0x25050f3cb90>,
#   <matplotlib.patches.Wedge at 0x25050f3da50>,
#   <matplotlib.patches.Wedge at 0x25050f3f950>,
#   <matplotlib.patches.Wedge at 0x25050f30650>,
#   <matplotlib.patches.Wedge at 0x25050f30d90>,
#   <matplotlib.patches.Wedge at 0x25050f330d0>,
#   <matplotlib.patches.Wedge at 0x25050f23e10>,
#   <matplotlib.patches.Wedge at 0x25050f203d0>,
#   <matplotlib.patches.Wedge at 0x25050f22250>,
#   <matplotlib.patches.Wedge at 0x25050f20a10>,
#   <matplotlib.patches.Wedge at 0x25050f1a3d0>,
#   <matplotlib.patches.Wedge at 0x25050f19390>,
#   <matplotlib.patches.Wedge at 0x25050f1b490>,
#   <matplotlib.patches.Wedge at 0x25050f0da90>,
#   <matplotlib.patches.Wedge at 0x25050f0ce50>,
#   <matplotlib.patches.Wedge at 0x25050f0ed90>,
#   <matplotlib.patches.Wedge at 0x25050efb0d0>,
#   <matplotlib.patches.Wedge at 0x25050ef8a10>,
#   <matplotlib.patches.Wedge at 0x25050ef9d50>,
#   <matplotlib.patches.Wedge at 0x25050efb710>,
#   <matplotlib.patches.Wedge at 0x25050eebe50>,
#   <matplotlib.patches.Wedge at 0x25050ee9790>,
#   <matplotlib.patches.Wedge at 0x25050eeb410>,
#   <matplotlib.patches.Wedge at 0x25050edf090>,
#   <matplotlib.patches.Wedge at 0x25050edc990>,
#   <matplotlib.patches.Wedge at 0x25050ede850>,
#   <matplotlib.patches.Wedge at 0x25050edde10>,
#   <matplotlib.patches.Wedge at 0x25050ecc6d0>,
#   <matplotlib.patches.Wedge at 0x25050ecd610>,
#   <matplotlib.patches.Wedge at 0x25050ecf690>,
#   <matplotlib.patches.Wedge at 0x25050eb1dd0>,
#   <matplotlib.patches.Wedge at 0x25050eb0cd0>,
#   <matplotlib.patches.Wedge at 0x25050eb2b50>,
#   <matplotlib.patches.Wedge at 0x25050ea5690>,
#   <matplotlib.patches.Wedge at 0x25050ea48d0>,
#   <matplotlib.patches.Wedge at 0x25050ea5f90>,
#   <matplotlib.patches.Wedge at 0x25050ea7d10>,
#   <matplotlib.patches.Wedge at 0x25050e9fa10>,
#   <matplotlib.patches.Wedge at 0x25050e9cc10>,
#   <matplotlib.patches.Wedge at 0x25050e9f3d0>,
#   <matplotlib.patches.Wedge at 0x25050e83390>,
#   <matplotlib.patches.Wedge at 0x25050e83350>,
#   <matplotlib.patches.Wedge at 0x25050e82010>,
#   <matplotlib.patches.Wedge at 0x25050e83a90>,
#   <matplotlib.patches.Wedge at 0x25050e70290>,
#   <matplotlib.patches.Wedge at 0x25050e70d50>,
#   <matplotlib.patches.Wedge at 0x25050e73110>,
#   <matplotlib.patches.Wedge at 0x25050e57510>,
#   <matplotlib.patches.Wedge at 0x25050e54590>,
#   <matplotlib.patches.Wedge at 0x25050e55e10>,
#   <matplotlib.patches.Wedge at 0x25050e57410>,
#   <matplotlib.patches.Wedge at 0x25050e3a050>,
#   <matplotlib.patches.Wedge at 0x25050e38890>,
#   <matplotlib.patches.Wedge at 0x25050e3b390>,
#   <matplotlib.patches.Wedge at 0x25050e10d50>,
#   <matplotlib.patches.Wedge at 0x25050e10e90>,
#   <matplotlib.patches.Wedge at 0x25050e12ad0>,
#   <matplotlib.patches.Wedge at 0x25050e07550>,
#   <matplotlib.patches.Wedge at 0x25050e050d0>,
#   <matplotlib.patches.Wedge at 0x25050e05ed0>,
#   <matplotlib.patches.Wedge at 0x25050e078d0>,
#   <matplotlib.patches.Wedge at 0x25050df5cd0>,
#   <matplotlib.patches.Wedge at 0x25050df5190>,
#   <matplotlib.patches.Wedge at 0x25050df7090>,
#   <matplotlib.patches.Wedge at 0x25050de3c90>,
#   <matplotlib.patches.Wedge at 0x25050de1c10>,
#   <matplotlib.patches.Wedge at 0x25050de11d0>,
#   <matplotlib.patches.Wedge at 0x25050de3990>,
#   <matplotlib.patches.Wedge at 0x25050dd4610>,
#   <matplotlib.patches.Wedge at 0x25050dd4f90>,
#   <matplotlib.patches.Wedge at 0x25050dd6d50>,
#   <matplotlib.patches.Wedge at 0x25050dc73d0>,
#   <matplotlib.patches.Wedge at 0x25050dc6250>,
#   <matplotlib.patches.Wedge at 0x25050dc6210>,
#   <matplotlib.patches.Wedge at 0x25050dc7fd0>,
#   <matplotlib.patches.Wedge at 0x25050dadc50>,
#   <matplotlib.patches.Wedge at 0x25050dad890>,
#   <matplotlib.patches.Wedge at 0x25050daf510>,
#   <matplotlib.patches.Wedge at 0x25050d9db50>,
#   <matplotlib.patches.Wedge at 0x25050d9c590>,
#   <matplotlib.patches.Wedge at 0x25050d9e190>,
#   <matplotlib.patches.Wedge at 0x25050d9cd90>,
#   <matplotlib.patches.Wedge at 0x25050d87010>,
#   <matplotlib.patches.Wedge at 0x25050d85710>,
#   <matplotlib.patches.Wedge at 0x25050d86c10>,
#   <matplotlib.patches.Wedge at 0x25050d77690>,
#   <matplotlib.patches.Wedge at 0x25050d74a50>,
#   <matplotlib.patches.Wedge at 0x25050d75b90>,
#   <matplotlib.patches.Wedge at 0x25050d77250>,
#   <matplotlib.patches.Wedge at 0x25050d68050>,
#   <matplotlib.patches.Wedge at 0x25050d69850>,
#   <matplotlib.patches.Wedge at 0x25050d6bcd0>,
#   <matplotlib.patches.Wedge at 0x25050d4ddd0>,
#   <matplotlib.patches.Wedge at 0x25050d4c910>,
#   <matplotlib.patches.Wedge at 0x25050d4ef50>,
#   <matplotlib.patches.Wedge at 0x25050d4c750>,
#   <matplotlib.patches.Wedge at 0x25050d41390>,
#   <matplotlib.patches.Wedge at 0x25050d41e10>,
#   <matplotlib.patches.Wedge at 0x25050d43c90>,
#   <matplotlib.patches.Wedge at 0x25050d34790>,
#   <matplotlib.patches.Wedge at 0x25050d34cd0>,
#   <matplotlib.patches.Wedge at 0x25050d36850>,
#   <matplotlib.patches.Wedge at 0x25050d23f10>,
#   <matplotlib.patches.Wedge at 0x25050d22650>,
#   <matplotlib.patches.Wedge at 0x25050d22010>,
#   <matplotlib.patches.Wedge at 0x25050d23990>,
#   <matplotlib.patches.Wedge at 0x25050d166d0>,
#   <matplotlib.patches.Wedge at 0x25050d14e90>,
#   <matplotlib.patches.Wedge at 0x25050d16d10>,
#   <matplotlib.patches.Wedge at 0x25050cff950>,
#   <matplotlib.patches.Wedge at 0x25050cfc690>,
#   <matplotlib.patches.Wedge at 0x25050cfe290>,
#   <matplotlib.patches.Wedge at 0x25050cff650>,
#   <matplotlib.patches.Wedge at 0x25050cf1a10>,
#   <matplotlib.patches.Wedge at 0x25050cf0f90>,
#   <matplotlib.patches.Wedge at 0x25050cf3010>,
#   <matplotlib.patches.Wedge at 0x25050cdce50>,
#   <matplotlib.patches.Wedge at 0x25050cdc390>,
#   <matplotlib.patches.Wedge at 0x25050cde250>,
#   <matplotlib.patches.Wedge at 0x25050cdcd10>,
#   <matplotlib.patches.Wedge at 0x25050ccc790>,
#   <matplotlib.patches.Wedge at 0x25050ccc810>,
#   <matplotlib.patches.Wedge at 0x25050ccf110>,
#   <matplotlib.patches.Wedge at 0x25050cc1450>,
#   <matplotlib.patches.Wedge at 0x25050cc0710>,
#   <matplotlib.patches.Wedge at 0x25050cc1fd0>,
#   <matplotlib.patches.Wedge at 0x25050cc2d10>,
#   <matplotlib.patches.Wedge at 0x25050cb1d90>,
#   <matplotlib.patches.Wedge at 0x25050cb16d0>,
#   <matplotlib.patches.Wedge at 0x25050cb3810>,
#   <matplotlib.patches.Wedge at 0x25050cab250>,
#   <matplotlib.patches.Wedge at 0x25050ca8d90>,
#   <matplotlib.patches.Wedge at 0x25050caaed0>,
#   <matplotlib.patches.Wedge at 0x25050ca8190>,
#   <matplotlib.patches.Wedge at 0x25050c89050>,
#   <matplotlib.patches.Wedge at 0x25050c89490>,
#   <matplotlib.patches.Wedge at 0x25050c8bf10>,
#   <matplotlib.patches.Wedge at 0x25050c769d0>,
#   <matplotlib.patches.Wedge at 0x25050c75190>,
#   <matplotlib.patches.Wedge at 0x25050c76f50>,
#   <matplotlib.patches.Wedge at 0x25050c64d10>,
#   <matplotlib.patches.Wedge at 0x25050c64550>,
#   <matplotlib.patches.Wedge at 0x25050c65e50>,
#   <matplotlib.patches.Wedge at 0x25050c67a10>,
#   <matplotlib.patches.Wedge at 0x25050b20dd0>,
#   <matplotlib.patches.Wedge at 0x25050b20c50>,
#   <matplotlib.patches.Wedge at 0x25050b22f90>,
#   <matplotlib.patches.Wedge at 0x25050b1ac10>,
#   <matplotlib.patches.Wedge at 0x25050b185d0>,
#   <matplotlib.patches.Wedge at 0x25050b19e90>,
#   <matplotlib.patches.Wedge at 0x25050b1bb90>,
#   <matplotlib.patches.Wedge at 0x25050afc050>,
#   <matplotlib.patches.Wedge at 0x25050afcf10>,
#   <matplotlib.patches.Wedge at 0x25050aff590>,
#   <matplotlib.patches.Wedge at 0x25050af3750>,
#   <matplotlib.patches.Wedge at 0x25050af0550>,
#   <matplotlib.patches.Wedge at 0x25050af20d0>,
#   <matplotlib.patches.Wedge at 0x25050af15d0>,
#   <matplotlib.patches.Wedge at 0x25050ad0910>,
#   <matplotlib.patches.Wedge at 0x25050ad17d0>,
#   <matplotlib.patches.Wedge at 0x25050ad3490>,
#   <matplotlib.patches.Wedge at 0x25050aca250>,
#   <matplotlib.patches.Wedge at 0x25050ac8950>,
#   <matplotlib.patches.Wedge at 0x25050aca450>,
#   <matplotlib.patches.Wedge at 0x25050acb690>,
#   <matplotlib.patches.Wedge at 0x25050abb250>,
#   <matplotlib.patches.Wedge at 0x25050ab9390>,
#   <matplotlib.patches.Wedge at 0x25050abb210>,
#   <matplotlib.patches.Wedge at 0x25050a9a6d0>,
#   <matplotlib.patches.Wedge at 0x25050a980d0>,
#   <matplotlib.patches.Wedge at 0x25050a9a390>,
#   <matplotlib.patches.Wedge at 0x25050a9b850>,
#   <matplotlib.patches.Wedge at 0x25050a8aa10>,
#   <matplotlib.patches.Wedge at 0x25050a89450>,
#   <matplotlib.patches.Wedge at 0x25050a8aad0>,
#   <matplotlib.patches.Wedge at 0x25050a7cfd0>,
#   <matplotlib.patches.Wedge at 0x25050a7c650>,
#   <matplotlib.patches.Wedge at 0x25050a7e750>,
#   <matplotlib.patches.Wedge at 0x25050a7f510>,
#   <matplotlib.patches.Wedge at 0x25050a6ec10>,
#   <matplotlib.patches.Wedge at 0x25050a6dc50>,
#   <matplotlib.patches.Wedge at 0x25050a6e950>,
#   <matplotlib.patches.Wedge at 0x25051075f50>,
#   <matplotlib.patches.Wedge at 0x25051075190>,
#   <matplotlib.patches.Wedge at 0x25051076510>,
#   <matplotlib.patches.Wedge at 0x250510765d0>,
#   <matplotlib.patches.Wedge at 0x250510cb8d0>,
#   <matplotlib.patches.Wedge at 0x250510c9290>,
#   <matplotlib.patches.Wedge at 0x250510cb310>,
#   <matplotlib.patches.Wedge at 0x25050d90710>,
#   <matplotlib.patches.Wedge at 0x25050d90b50>,
#   <matplotlib.patches.Wedge at 0x25050d923d0>,
#   <matplotlib.patches.Wedge at 0x2505108ced0>,
#   <matplotlib.patches.Wedge at 0x2505108c910>,
#   <matplotlib.patches.Wedge at 0x2505108db10>,
#   <matplotlib.patches.Wedge at 0x2505108f4d0>,
#   <matplotlib.patches.Wedge at 0x25050addf50>,
#   <matplotlib.patches.Wedge at 0x25050adcb10>,
#   <matplotlib.patches.Wedge at 0x25050adecd0>,
#   <matplotlib.patches.Wedge at 0x25050a2f3d0>,
#   <matplotlib.patches.Wedge at 0x25050a2fb50>,
#   <matplotlib.patches.Wedge at 0x25050a2e750>,
#   <matplotlib.patches.Wedge at 0x25050a2d050>,
#   <matplotlib.patches.Wedge at 0x25050e62d10>,
#   <matplotlib.patches.Wedge at 0x25050e60690>,
#   <matplotlib.patches.Wedge at 0x25050e62ed0>,
#   <matplotlib.patches.Wedge at 0x250510d5310>,
#   <matplotlib.patches.Wedge at 0x250510d6290>,
#   <matplotlib.patches.Wedge at 0x250510d7e90>,
#   <matplotlib.patches.Wedge at 0x25050bad1d0>,
#   <matplotlib.patches.Wedge at 0x25050badb90>,
#   <matplotlib.patches.Wedge at 0x25050baf9d0>,
#   <matplotlib.patches.Wedge at 0x25050bafa10>,
#   <matplotlib.patches.Wedge at 0x25050ba1c90>,
#   <matplotlib.patches.Wedge at 0x25050ba3690>,
#   <matplotlib.patches.Wedge at 0x25050ba0b90>,
#   <matplotlib.patches.Wedge at 0x2504e637d90>,
#   <matplotlib.patches.Wedge at 0x2504ee92e50>,
#   <matplotlib.patches.Wedge at 0x2504e29f850>,
#   <matplotlib.patches.Wedge at 0x2504eee9710>,
#   <matplotlib.patches.Wedge at 0x2504e347410>,
#   <matplotlib.patches.Wedge at 0x2504ec2c550>,
#   <matplotlib.patches.Wedge at 0x2504e3ab010>,
#   <matplotlib.patches.Wedge at 0x2504ed260d0>,
#   <matplotlib.patches.Wedge at 0x2504ed26e90>,
#   <matplotlib.patches.Wedge at 0x2504ef0d5d0>,
#   <matplotlib.patches.Wedge at 0x2504ed1a610>,
#   <matplotlib.patches.Wedge at 0x2504ed1add0>,
#   <matplotlib.patches.Wedge at 0x2504edc5990>,
#   <matplotlib.patches.Wedge at 0x2504ed49cd0>,
#   <matplotlib.patches.Wedge at 0x2504ee98c10>,
#   <matplotlib.patches.Wedge at 0x2504ed2d090>,
#   <matplotlib.patches.Wedge at 0x2504ef2ec10>,
#   <matplotlib.patches.Wedge at 0x2504ed14b10>,
#   <matplotlib.patches.Wedge at 0x2504ed16850>,
#   <matplotlib.patches.Wedge at 0x2504ed14710>,
#   <matplotlib.patches.Wedge at 0x2504ed513d0>,
#   <matplotlib.patches.Wedge at 0x2504ed53350>,
#   <matplotlib.patches.Wedge at 0x2504ec6fe50>,
#   <matplotlib.patches.Wedge at 0x2504dc67050>,
#   <matplotlib.patches.Wedge at 0x2504dc650d0>,
#   <matplotlib.patches.Wedge at 0x2504ef1bd50>,
#   <matplotlib.patches.Wedge at 0x2504e69c250>,
#   <matplotlib.patches.Wedge at 0x2504e3cdf50>,
#   <matplotlib.patches.Wedge at 0x2504e3ccf90>,
#   <matplotlib.patches.Wedge at 0x2504ed3a3d0>,
#   <matplotlib.patches.Wedge at 0x2504ed389d0>,
#   <matplotlib.patches.Wedge at 0x2504ed3b9d0>,
#   <matplotlib.patches.Wedge at 0x2504e6af950>,
#   <matplotlib.patches.Wedge at 0x2504ef73050>,
#   <matplotlib.patches.Wedge at 0x2504ef71710>,
#   <matplotlib.patches.Wedge at 0x2504ef73490>,
#   <matplotlib.patches.Wedge at 0x2504ef71610>,
#   <matplotlib.patches.Wedge at 0x2504ef79650>,
#   <matplotlib.patches.Wedge at 0x2504ef7be10>,
#   <matplotlib.patches.Wedge at 0x2504ef79050>,
#   <matplotlib.patches.Wedge at 0x25050a26e90>,
#   <matplotlib.patches.Wedge at 0x25050a27e90>,
#   <matplotlib.patches.Wedge at 0x25050a26450>,
#   <matplotlib.patches.Wedge at 0x2504e409310>,
#   <matplotlib.patches.Wedge at 0x2504e40a650>,
#   <matplotlib.patches.Wedge at 0x2504e409b10>,
#   <matplotlib.patches.Wedge at 0x2504e33afd0>,
#   <matplotlib.patches.Wedge at 0x250509a4cd0>,
#   <matplotlib.patches.Wedge at 0x250509a5550>,
#   <matplotlib.patches.Wedge at 0x250509a7850>,
#   <matplotlib.patches.Wedge at 0x2504e3f74d0>,
#   <matplotlib.patches.Wedge at 0x2504e3f6310>,
#   <matplotlib.patches.Wedge at 0x2504ef813d0>,
#   <matplotlib.patches.Wedge at 0x2504ef81110>,
#   <matplotlib.patches.Wedge at 0x2504ef832d0>,
#   <matplotlib.patches.Wedge at 0x2504ef83290>,
#   <matplotlib.patches.Wedge at 0x2504c4e5890>,
#   <matplotlib.patches.Wedge at 0x250509ae4d0>,
#   <matplotlib.patches.Wedge at 0x250509acbd0>,
#   <matplotlib.patches.Wedge at 0x250509ac750>,
#   <matplotlib.patches.Wedge at 0x250509ab190>,
#   <matplotlib.patches.Wedge at 0x250509aaa10>,
#   <matplotlib.patches.Wedge at 0x250509aba50>,
#   <matplotlib.patches.Wedge at 0x250509c0110>,
#   <matplotlib.patches.Wedge at 0x250509c1490>,
#   <matplotlib.patches.Wedge at 0x250509c0f90>,
#   <matplotlib.patches.Wedge at 0x250509c3250>,
#   <matplotlib.patches.Wedge at 0x250509cc8d0>,
#   <matplotlib.patches.Wedge at 0x250509cdb90>,
#   <matplotlib.patches.Wedge at 0x250509cc790>,
#   <matplotlib.patches.Wedge at 0x2504e3ed050>,
#   <matplotlib.patches.Wedge at 0x2504e3eefd0>,
#   <matplotlib.patches.Wedge at 0x2504e284210>,
#   <matplotlib.patches.Wedge at 0x250509d2b50>,
#   <matplotlib.patches.Wedge at 0x250509d3c10>,
#   <matplotlib.patches.Wedge at 0x250509d0310>,
#   <matplotlib.patches.Wedge at 0x25050b71190>,
#   <matplotlib.patches.Wedge at 0x25050b73750>,
#   <matplotlib.patches.Wedge at 0x25050b72dd0>,
#   <matplotlib.patches.Wedge at 0x25050b74a50>,
#   <matplotlib.patches.Wedge at 0x25050b75dd0>,
#   <matplotlib.patches.Wedge at 0x25050b74c50>,
#   <matplotlib.patches.Wedge at 0x25050b8bd50>,
#   <matplotlib.patches.Wedge at 0x25050b89d90>,
#   <matplotlib.patches.Wedge at 0x25050b8b010>,
#   <matplotlib.patches.Wedge at 0x25050b89cd0>,
#   <matplotlib.patches.Wedge at 0x25050981410>,
#   <matplotlib.patches.Wedge at 0x250509811d0>,
#   <matplotlib.patches.Wedge at 0x250509820d0>,
#   <matplotlib.patches.Wedge at 0x2505096e650>,
#   <matplotlib.patches.Wedge at 0x2505096cb50>,
#   <matplotlib.patches.Wedge at 0x2505096d690>,
#   <matplotlib.patches.Wedge at 0x2505096f9d0>,
#   <matplotlib.patches.Wedge at 0x2505094af50>,
#   <matplotlib.patches.Wedge at 0x25050948b10>,
#   <matplotlib.patches.Wedge at 0x2505094b010>,
#   <matplotlib.patches.Wedge at 0x250508b2650>,
#   <matplotlib.patches.Wedge at 0x250508b34d0>,
#   <matplotlib.patches.Wedge at 0x250508b1950>,
#   <matplotlib.patches.Wedge at 0x250508b3b90>,
#   <matplotlib.patches.Wedge at 0x25050884d90>,
#   <matplotlib.patches.Wedge at 0x25050885450>,
#   <matplotlib.patches.Wedge at 0x25050886ed0>,
#   <matplotlib.patches.Wedge at 0x2505084f910>,
#   <matplotlib.patches.Wedge at 0x2505084c6d0>,
#   <matplotlib.patches.Wedge at 0x2505084db10>,
#   <matplotlib.patches.Wedge at 0x2505084fcd0>,
#   <matplotlib.patches.Wedge at 0x25050826210>,
#   <matplotlib.patches.Wedge at 0x250508253d0>,
#   <matplotlib.patches.Wedge at 0x25050826f10>,
#   <matplotlib.patches.Wedge at 0x25050815010>,
#   <matplotlib.patches.Wedge at 0x25050814090>,
#   <matplotlib.patches.Wedge at 0x250508163d0>,
#   <matplotlib.patches.Wedge at 0x25050815590>,
#   <matplotlib.patches.Wedge at 0x2505080d990>,
#   <matplotlib.patches.Wedge at 0x2505080c690>,
#   <matplotlib.patches.Wedge at 0x2505080f550>,
#   <matplotlib.patches.Wedge at 0x250507c2a50>,
#   <matplotlib.patches.Wedge at 0x250507c00d0>,
#   <matplotlib.patches.Wedge at 0x250507c2350>,
#   <matplotlib.patches.Wedge at 0x250507c3550>,
#   <matplotlib.patches.Wedge at 0x250507ab350>,
#   <matplotlib.patches.Wedge at 0x250507a98d0>,
#   <matplotlib.patches.Wedge at 0x250507ab310>,
#   <matplotlib.patches.Wedge at 0x25050789c10>,
#   <matplotlib.patches.Wedge at 0x25050788a10>,
#   <matplotlib.patches.Wedge at 0x25050789990>,
#   <matplotlib.patches.Wedge at 0x2505077c8d0>,
#   <matplotlib.patches.Wedge at 0x2505077ce10>,
#   <matplotlib.patches.Wedge at 0x2505077ce90>,
#   <matplotlib.patches.Wedge at 0x2505077fe50>,
#   <matplotlib.patches.Wedge at 0x25050748e10>,
#   <matplotlib.patches.Wedge at 0x25050748a90>,
#   <matplotlib.patches.Wedge at 0x2505074ad50>,
#   <matplotlib.patches.Wedge at 0x2505073b710>,
#   <matplotlib.patches.Wedge at 0x2505073a250>,
#   <matplotlib.patches.Wedge at 0x25050739b10>,
#   <matplotlib.patches.Wedge at 0x2505073b4d0>,
#   <matplotlib.patches.Wedge at 0x250506e6e90>,
#   <matplotlib.patches.Wedge at 0x250506e45d0>,
#   <matplotlib.patches.Wedge at 0x250506e6c50>,
#   <matplotlib.patches.Wedge at 0x250506ad150>,
#   <matplotlib.patches.Wedge at 0x250506ade10>,
#   <matplotlib.patches.Wedge at 0x250506ad710>,
#   <matplotlib.patches.Wedge at 0x250506af890>,
#   <matplotlib.patches.Wedge at 0x2505069d950>,
#   <matplotlib.patches.Wedge at 0x2505069c6d0>,
#   <matplotlib.patches.Wedge at 0x2505069e990>,
#   <matplotlib.patches.Wedge at 0x2505065a310>,
#   <matplotlib.patches.Wedge at 0x25050659d90>,
#   <matplotlib.patches.Wedge at 0x25050659e50>,
#   <matplotlib.patches.Wedge at 0x2505065b650>,
#   <matplotlib.patches.Wedge at 0x2505064b2d0>,
#   <matplotlib.patches.Wedge at 0x25050648e90>,
#   <matplotlib.patches.Wedge at 0x2505064a990>,
#   <matplotlib.patches.Wedge at 0x250505fad90>,
#   <matplotlib.patches.Wedge at 0x250505f9c50>,
#   <matplotlib.patches.Wedge at 0x250505f9690>,
#   <matplotlib.patches.Wedge at 0x250505fb990>,
#   <matplotlib.patches.Wedge at 0x250505ece50>,
#   <matplotlib.patches.Wedge at 0x250505ec950>,
#   <matplotlib.patches.Wedge at 0x250505ef290>,
#   <matplotlib.patches.Wedge at 0x250505d38d0>,
#   <matplotlib.patches.Wedge at 0x250505d2650>,
#   <matplotlib.patches.Wedge at 0x250505d2010>,
#   <matplotlib.patches.Wedge at 0x250505d3e50>,
#   <matplotlib.patches.Wedge at 0x250505c5590>,
#   <matplotlib.patches.Wedge at 0x250505c51d0>,
#   <matplotlib.patches.Wedge at 0x250505c6fd0>,
#   <matplotlib.patches.Wedge at 0x250505a6cd0>,
#   <matplotlib.patches.Wedge at 0x250505a5d90>,
#   <matplotlib.patches.Wedge at 0x250505a5710>,
#   <matplotlib.patches.Wedge at 0x250505a7c10>,
#   <matplotlib.patches.Wedge at 0x2505053b2d0>,
#   <matplotlib.patches.Wedge at 0x25050538990>,
#   <matplotlib.patches.Wedge at 0x2505053a7d0>,
#   <matplotlib.patches.Wedge at 0x250500b6890>,
#   <matplotlib.patches.Wedge at 0x250500b42d0>,
#   <matplotlib.patches.Wedge at 0x250500b58d0>,
#   <matplotlib.patches.Wedge at 0x250500b7650>,
#   <matplotlib.patches.Wedge at 0x2504df62150>,
#   <matplotlib.patches.Wedge at 0x2504df63dd0>,
#   <matplotlib.patches.Wedge at 0x2504ef55450>,
#   <matplotlib.patches.Wedge at 0x2504ef569d0>,
#   <matplotlib.patches.Wedge at 0x2504e3a6250>,
#   <matplotlib.patches.Wedge at 0x2504e3a7810>,
#   <matplotlib.patches.Wedge at 0x2504ef639d0>,
#   <matplotlib.patches.Wedge at 0x2504ef62e90>,
#   <matplotlib.patches.Wedge at 0x2504ef61bd0>,
#   <matplotlib.patches.Wedge at 0x2504e368e10>,
#   <matplotlib.patches.Wedge at 0x2504ed0b250>,
#   <matplotlib.patches.Wedge at 0x2504ed0be90>,
#   <matplotlib.patches.Wedge at 0x2504eddc090>,
#   <matplotlib.patches.Wedge at 0x2504ef52c90>,
#   <matplotlib.patches.Wedge at 0x2504eedbc50>,
#   <matplotlib.patches.Wedge at 0x2504dcb5f10>,
#   <matplotlib.patches.Wedge at 0x2504dcc5910>,
#   <matplotlib.patches.Wedge at 0x2504dd2b2d0>,
#   <matplotlib.patches.Wedge at 0x2504dd28c90>,
#   <matplotlib.patches.Wedge at 0x2504dd2b390>,
#   <matplotlib.patches.Wedge at 0x2504e391990>,
#   <matplotlib.patches.Wedge at 0x2504e3780d0>,
#   <matplotlib.patches.Wedge at 0x2504e682ed0>,
#   <matplotlib.patches.Wedge at 0x2504e683250>,
#   <matplotlib.patches.Wedge at 0x25050939390>,
#   <matplotlib.patches.Wedge at 0x25050938fd0>,
#   <matplotlib.patches.Wedge at 0x2505093b2d0>,
#   <matplotlib.patches.Wedge at 0x25050621410>,
#   <matplotlib.patches.Wedge at 0x25050620510>,
#   <matplotlib.patches.Wedge at 0x25050622b50>,
#   <matplotlib.patches.Wedge at 0x250506230d0>,
#   <matplotlib.patches.Wedge at 0x2505089dd50>,
#   <matplotlib.patches.Wedge at 0x2505089d150>,
#   <matplotlib.patches.Wedge at 0x2505089f450>,
#   <matplotlib.patches.Wedge at 0x2504e375c90>,
#   <matplotlib.patches.Wedge at 0x2504ec08650>,
#   <matplotlib.patches.Wedge at 0x2504ec0a950>,
#   <matplotlib.patches.Wedge at 0x2504e35ea50>,
#   <matplotlib.patches.Wedge at 0x250509a1450>,
#   <matplotlib.patches.Wedge at 0x250509a0d90>,
#   <matplotlib.patches.Wedge at 0x250509a2150>,
#   <matplotlib.patches.Wedge at 0x250509a0610>,
#   <matplotlib.patches.Wedge at 0x2504e3a3450>,
#   <matplotlib.patches.Wedge at 0x2504e3a1310>,
#   <matplotlib.patches.Wedge at 0x2504dc98190>,
#   <matplotlib.patches.Wedge at 0x2504dc98890>,
#   <matplotlib.patches.Wedge at 0x2504dc9b850>,
#   <matplotlib.patches.Wedge at 0x2504dc58290>,
#   <matplotlib.patches.Wedge at 0x2504dc5a050>,
#   <matplotlib.patches.Wedge at 0x2504dc5acd0>,
#   <matplotlib.patches.Wedge at 0x25049d20950>,
#   <matplotlib.patches.Wedge at 0x2504c2c8350>,
#   <matplotlib.patches.Wedge at 0x2504c2cb8d0>,
#   <matplotlib.patches.Wedge at 0x2504c2c8750>,
#   <matplotlib.patches.Wedge at 0x2504dd46310>,
#   <matplotlib.patches.Wedge at 0x2504c788c90>,
#   <matplotlib.patches.Wedge at 0x2504c7897d0>,
#   <matplotlib.patches.Wedge at 0x2504c789c10>,
#   <matplotlib.patches.Wedge at 0x2504e73a190>,
#   <matplotlib.patches.Wedge at 0x2504e799910>,
#   <matplotlib.patches.Wedge at 0x2504e75f6d0>,
#   <matplotlib.patches.Wedge at 0x2504de901d0>,
#   <matplotlib.patches.Wedge at 0x2504dd5e5d0>,
#   <matplotlib.patches.Wedge at 0x2504e673350>,
#   <matplotlib.patches.Wedge at 0x2504a23a1d0>,
#   <matplotlib.patches.Wedge at 0x2504a23b4d0>,
#   <matplotlib.patches.Wedge at 0x2504a23b390>,
#   <matplotlib.patches.Wedge at 0x2504e6a4b90>,
#   <matplotlib.patches.Wedge at 0x2504e6a6a10>,
#   <matplotlib.patches.Wedge at 0x2504da75d90>,
#   <matplotlib.patches.Wedge at 0x2504df33b10>,
#   <matplotlib.patches.Wedge at 0x2504dc93410>,
#   <matplotlib.patches.Wedge at 0x2504dc92710>,
#   <matplotlib.patches.Wedge at 0x2504dc937d0>,
#   <matplotlib.patches.Wedge at 0x2504de834d0>,
#   <matplotlib.patches.Wedge at 0x2504de839d0>,
#   <matplotlib.patches.Wedge at 0x2504dc6b590>,
#   <matplotlib.patches.Wedge at 0x2504dc69ed0>,
#   <matplotlib.patches.Wedge at 0x2504dc68f50>,
#   <matplotlib.patches.Wedge at 0x2504dce6750>,
#   <matplotlib.patches.Wedge at 0x2504dce5ed0>,
#   <matplotlib.patches.Wedge at 0x2504dce6710>,
#   <matplotlib.patches.Wedge at 0x2504dcff290>,
#   <matplotlib.patches.Wedge at 0x2504dcfca50>,
#   <matplotlib.patches.Wedge at 0x2504debe950>,
#   <matplotlib.patches.Wedge at 0x2504dab8d10>,
#   <matplotlib.patches.Wedge at 0x2504dabb990>,
#   <matplotlib.patches.Wedge at 0x2504dab8650>,
#   <matplotlib.patches.Wedge at 0x2504dc8c810>,
#   <matplotlib.patches.Wedge at 0x2504dc8c4d0>,
#   <matplotlib.patches.Wedge at 0x2504dc8f190>,
#   <matplotlib.patches.Wedge at 0x2504df117d0>,
#   <matplotlib.patches.Wedge at 0x2504df13190>,
#   <matplotlib.patches.Wedge at 0x2504ec02f50>,
#   <matplotlib.patches.Wedge at 0x2504ec01e10>,
#   <matplotlib.patches.Wedge at 0x2504e396750>,
#   <matplotlib.patches.Wedge at 0x2504e121490>,
#   <matplotlib.patches.Wedge at 0x2504dc4c890>,
#   <matplotlib.patches.Wedge at 0x2504dc4d2d0>,
#   <matplotlib.patches.Wedge at 0x2504dc4f6d0>,
#   <matplotlib.patches.Wedge at 0x2504dc3fc50>,
#   <matplotlib.patches.Wedge at 0x2504dc3ec10>,
#   <matplotlib.patches.Wedge at 0x2504dc3c610>,
#   <matplotlib.patches.Wedge at 0x2504e7d8790>,
#   <matplotlib.patches.Wedge at 0x2504def5cd0>,
#   <matplotlib.patches.Wedge at 0x2504dc12f50>,
#   <matplotlib.patches.Wedge at 0x2504dc12b50>,
#   <matplotlib.patches.Wedge at 0x2504dc12250>,
#   <matplotlib.patches.Wedge at 0x2504dc0b710>,
#   <matplotlib.patches.Wedge at 0x2504dc09310>,
#   <matplotlib.patches.Wedge at 0x2504dc0b250>,
#   <matplotlib.patches.Wedge at 0x2504dc0bf50>,
#   <matplotlib.patches.Wedge at 0x2504dbf9550>,
#   <matplotlib.patches.Wedge at 0x2504dbf9910>,
#   <matplotlib.patches.Wedge at 0x2504dbfad50>,
#   <matplotlib.patches.Wedge at 0x2504dbebd50>,
#   <matplotlib.patches.Wedge at 0x2504dbe9b10>,
#   <matplotlib.patches.Wedge at 0x2504dbe91d0>,
#   <matplotlib.patches.Wedge at 0x2504d8bcfd0>,
#   <matplotlib.patches.Wedge at 0x2504d853450>,
#   <matplotlib.patches.Wedge at 0x2504d851e10>,
#   <matplotlib.patches.Wedge at 0x2504d8512d0>,
#   <matplotlib.patches.Wedge at 0x2504d850b10>,
#   <matplotlib.patches.Wedge at 0x2504c338510>,
#   <matplotlib.patches.Wedge at 0x2504c33acd0>,
#   <matplotlib.patches.Wedge at 0x2504c33ab90>,
#   <matplotlib.patches.Wedge at 0x2504c3bae50>,
#   <matplotlib.patches.Wedge at 0x2504c3b98d0>,
#   <matplotlib.patches.Wedge at 0x2504c3b88d0>,
#   <matplotlib.patches.Wedge at 0x2504c3b8e10>,
#   <matplotlib.patches.Wedge at 0x2504c561950>,
#   <matplotlib.patches.Wedge at 0x2504c562b10>,
#   <matplotlib.patches.Wedge at 0x2504c561210>,
#   <matplotlib.patches.Wedge at 0x2504c34e610>,
#   <matplotlib.patches.Wedge at 0x2504c34ec10>,
#   <matplotlib.patches.Wedge at 0x2504c34efd0>,
#   <matplotlib.patches.Wedge at 0x2504c574190>,
#   <matplotlib.patches.Wedge at 0x2504c577dd0>,
#   <matplotlib.patches.Wedge at 0x2504c50b210>,
#   <matplotlib.patches.Wedge at 0x2504c508d90>,
#   <matplotlib.patches.Wedge at 0x2504c50b890>,
#   <matplotlib.patches.Wedge at 0x2504c382e10>,
#   <matplotlib.patches.Wedge at 0x2504c383850>,
#   <matplotlib.patches.Wedge at 0x2504c383590>,
#   <matplotlib.patches.Wedge at 0x2504c382dd0>,
#   <matplotlib.patches.Wedge at 0x2504c366490>,
#   <matplotlib.patches.Wedge at 0x2504c364250>,
#   <matplotlib.patches.Wedge at 0x2504c365350>,
#   <matplotlib.patches.Wedge at 0x2504c3ac5d0>,
#   <matplotlib.patches.Wedge at 0x2504c3aee50>,
#   <matplotlib.patches.Wedge at 0x2504c3ade90>,
#   <matplotlib.patches.Wedge at 0x2504c56afd0>,
#   <matplotlib.patches.Wedge at 0x2504c56b110>,
#   <matplotlib.patches.Wedge at 0x25049000a10>,
#   <matplotlib.patches.Wedge at 0x25049001150>,
#   <matplotlib.patches.Wedge at 0x250487226d0>,
#   <matplotlib.patches.Wedge at 0x2504a1d9bd0>,
#   <matplotlib.patches.Wedge at 0x2504a1d8250>,
#   <matplotlib.patches.Wedge at 0x2504a1da0d0>,
#   <matplotlib.patches.Wedge at 0x2504c38cd10>,
#   <matplotlib.patches.Wedge at 0x2504c38f490>,
#   <matplotlib.patches.Wedge at 0x2504c38e750>,
#   <matplotlib.patches.Wedge at 0x2504c38f910>,
#   <matplotlib.patches.Wedge at 0x2504c4ce750>,
#   <matplotlib.patches.Wedge at 0x2504c4fccd0>,
#   <matplotlib.patches.Wedge at 0x25048eecd50>,
#   <matplotlib.patches.Wedge at 0x250492c73d0>,
#   <matplotlib.patches.Wedge at 0x250486e6010>,
#   <matplotlib.patches.Wedge at 0x2504c59f350>,
#   <matplotlib.patches.Wedge at 0x2504c59c2d0>,
#   <matplotlib.patches.Wedge at 0x2504c59f550>,
#   <matplotlib.patches.Wedge at 0x2504c3a8c90>,
#   <matplotlib.patches.Wedge at 0x2504c3a8bd0>,
#   <matplotlib.patches.Wedge at 0x2504c3ab550>,
#   <matplotlib.patches.Wedge at 0x2504c3ab4d0>,
#   <matplotlib.patches.Wedge at 0x2504c6fc4d0>,
#   <matplotlib.patches.Wedge at 0x2504c6fd210>,
#   <matplotlib.patches.Wedge at 0x2504c6fd510>,
#   <matplotlib.patches.Wedge at 0x25048a55a10>,
#   <matplotlib.patches.Wedge at 0x2504c4517d0>,
#   <matplotlib.patches.Wedge at 0x2504c453890>,
#   <matplotlib.patches.Wedge at 0x2504c453c10>,
#   <matplotlib.patches.Wedge at 0x2504c30d650>,
#   <matplotlib.patches.Wedge at 0x2504c30c210>,
#   <matplotlib.patches.Wedge at 0x2504c30d550>,
#   <matplotlib.patches.Wedge at 0x2504c30d2d0>,
#   <matplotlib.patches.Wedge at 0x2504a21b310>,
#   <matplotlib.patches.Wedge at 0x2504a21a4d0>,
#   <matplotlib.patches.Wedge at 0x2504a219710>,
#   <matplotlib.patches.Wedge at 0x2504ed5e710>,
#   <matplotlib.patches.Wedge at 0x2504c7432d0>,
#   <matplotlib.patches.Wedge at 0x2504c741b50>,
#   <matplotlib.patches.Wedge at 0x2504c743350>,
#   <matplotlib.patches.Wedge at 0x2504a05fe10>,
#   <matplotlib.patches.Wedge at 0x2504c2bc950>,
#   <matplotlib.patches.Wedge at 0x2504c2bcd90>,
#   <matplotlib.patches.Wedge at 0x2504c2bc490>,
#   <matplotlib.patches.Wedge at 0x2504c2be710>,
#   <matplotlib.patches.Wedge at 0x2504c47b7d0>,
#   <matplotlib.patches.Wedge at 0x2504c47a190>,
#   <matplotlib.patches.Wedge at 0x2504c479610>,
#   <matplotlib.patches.Wedge at 0x2504dc8a7d0>,
#   <matplotlib.patches.Wedge at 0x2504dc89410>,
#   <matplotlib.patches.Wedge at 0x2504dc8bd50>,
#   <matplotlib.patches.Wedge at 0x2504d808610>,
#   <matplotlib.patches.Wedge at 0x2504d80ae50>,
#   <matplotlib.patches.Wedge at 0x2504d80af50>,
#   <matplotlib.patches.Wedge at 0x2504c2d98d0>,
#   <matplotlib.patches.Wedge at 0x2504c2d84d0>,
#   <matplotlib.patches.Wedge at 0x2504c2da390>,
#   <matplotlib.patches.Wedge at 0x2504c2db2d0>,
#   <matplotlib.patches.Wedge at 0x2504a279790>,
#   <matplotlib.patches.Wedge at 0x2504a27b550>,
#   <matplotlib.patches.Wedge at 0x2504a278710>,
#   <matplotlib.patches.Wedge at 0x2504a279c90>,
#   <matplotlib.patches.Wedge at 0x2504c3db290>,
#   <matplotlib.patches.Wedge at 0x2504c3da090>,
#   <matplotlib.patches.Wedge at 0x2504c3d9110>,
#   <matplotlib.patches.Wedge at 0x2504dca8c90>,
#   <matplotlib.patches.Wedge at 0x2504dcabe90>,
#   <matplotlib.patches.Wedge at 0x2504dca9850>,
#   <matplotlib.patches.Wedge at 0x2504976d350>,
#   <matplotlib.patches.Wedge at 0x2504c3f9ad0>,
#   <matplotlib.patches.Wedge at 0x2504c3f9910>,
#   <matplotlib.patches.Wedge at 0x2504c3fbd10>,
#   <matplotlib.patches.Wedge at 0x2504c74c590>,
#   <matplotlib.patches.Wedge at 0x2504c74c450>,
#   <matplotlib.patches.Wedge at 0x2504d8c4790>,
#   <matplotlib.patches.Wedge at 0x2504df05290>,
#   <matplotlib.patches.Wedge at 0x2504df05f90>,
#   <matplotlib.patches.Wedge at 0x2504c780b10>,
#   <matplotlib.patches.Wedge at 0x2504c783f10>,
#   <matplotlib.patches.Wedge at 0x2504c781e50>,
#   <matplotlib.patches.Wedge at 0x2504901e690>,
#   <matplotlib.patches.Wedge at 0x2504c391990>,
#   <matplotlib.patches.Wedge at 0x2504c393290>,
#   <matplotlib.patches.Wedge at 0x2504c393190>,
#   <matplotlib.patches.Wedge at 0x2504c393b50>,
#   <matplotlib.patches.Wedge at 0x2504c36e410>,
#   <matplotlib.patches.Wedge at 0x2504c36d590>,
#   <matplotlib.patches.Wedge at 0x2504c36db90>,
#   <matplotlib.patches.Wedge at 0x2504dc49910>,
#   <matplotlib.patches.Wedge at 0x2504dc49d50>,
#   <matplotlib.patches.Wedge at 0x2504dc4b890>,
#   <matplotlib.patches.Wedge at 0x2504c416ad0>,
#   <matplotlib.patches.Wedge at 0x2504c414990>,
#   <matplotlib.patches.Wedge at 0x2504c416950>,
#   <matplotlib.patches.Wedge at 0x2504c4079d0>,
#   <matplotlib.patches.Wedge at 0x2504c404a10>,
#   <matplotlib.patches.Wedge at 0x2504c407350>,
#   <matplotlib.patches.Wedge at 0x2504c4043d0>,
#   <matplotlib.patches.Wedge at 0x2504c53e590>,
#   <matplotlib.patches.Wedge at 0x25049151250>,
#   <matplotlib.patches.Wedge at 0x2504a18b990>,
#   <matplotlib.patches.Wedge at 0x2504c6e57d0>,
#   <matplotlib.patches.Wedge at 0x2504c6e4b90>,
#   <matplotlib.patches.Wedge at 0x2504c6e7050>,
#   <matplotlib.patches.Wedge at 0x2504a1d0310>,
#   <matplotlib.patches.Wedge at 0x2504a1d3ad0>,
#   <matplotlib.patches.Wedge at 0x2504a1d08d0>,
#   <matplotlib.patches.Wedge at 0x2504a1d0d10>,
#   <matplotlib.patches.Wedge at 0x2504904fc10>,
#   <matplotlib.patches.Wedge at 0x2504904eb50>,
#   <matplotlib.patches.Wedge at 0x2504904c050>,
#   <matplotlib.patches.Wedge at 0x2504d7f5510>,
#   <matplotlib.patches.Wedge at 0x2504d7f5710>,
#   <matplotlib.patches.Wedge at 0x2504d7f4d50>,
#   <matplotlib.patches.Wedge at 0x2504c3b1610>,
#   <matplotlib.patches.Wedge at 0x2504c3b3310>,
#   <matplotlib.patches.Wedge at 0x2504c3b3910>,
#   <matplotlib.patches.Wedge at 0x2504c45b1d0>,
#   <matplotlib.patches.Wedge at 0x2504c45bbd0>,
#   <matplotlib.patches.Wedge at 0x2504c45a550>,
#   <matplotlib.patches.Wedge at 0x2504c45bb90>,
#   <matplotlib.patches.Wedge at 0x2504df55a90>,
#   <matplotlib.patches.Wedge at 0x2504df56e90>,
#   <matplotlib.patches.Wedge at 0x2504c3fc290>,
#   <matplotlib.patches.Wedge at 0x2504c3fed90>,
#   <matplotlib.patches.Wedge at 0x2504c3fcf50>,
#   <matplotlib.patches.Wedge at 0x2504c3ffb50>,
#   <matplotlib.patches.Wedge at 0x2504d957f50>,
#   <matplotlib.patches.Wedge at 0x2504d954810>,
#   <matplotlib.patches.Wedge at 0x2504c4adc50>,
#   <matplotlib.patches.Wedge at 0x2504c4af790>,
#   <matplotlib.patches.Wedge at 0x2504c4af350>,
#   <matplotlib.patches.Wedge at 0x2504c749f90>,
#   <matplotlib.patches.Wedge at 0x2504c7490d0>,
#   <matplotlib.patches.Wedge at 0x2504c749450>,
#   <matplotlib.patches.Wedge at 0x2504c4b83d0>,
#   <matplotlib.patches.Wedge at 0x2504c4b9490>,
#   <matplotlib.patches.Wedge at 0x2504c4b87d0>],
#  [Text(1.1, 0.0, ''),
#   Text(1.0999535904694522, 0.010104395744480493, ''),
#   Text(1.0995823377212235, 0.030309776830746465, ''),
#   Text(1.0988399575287826, 0.05050492785999538, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.097726700457871, 0.07068303263072069, ''),
#   Text(1.0962429422513844, 0.09083728069481341, ''),
#   Text(1.0943891837025526, 0.11096086965620235, ''),
#   Text(1.0921660504859152, 0.13104700746677672, ''),
#   Text(1.09091619799659, 0.14107391306923098, ''),
#   Text(1.09091619799659, 0.14107391306923098, ''),
#   Text(1.09091619799659, 0.14107391306923098, ''),
#   Text(1.0895742929461443, 0.15108891471881597, ''),
#   Text(1.088140448565821, 0.16109116734003165, ''),
#   Text(1.0866147858447917, 0.17107982693315338, ''),
#   Text(1.0849974335199486, 0.1810540506454493, ''),
#   Text(1.083288528065041, 0.19101299684230105, ''),
#   Text(1.08148821367916, 0.2009558251782219, ''),
#   Text(1.0795966422745695, 0.2108816966677656, ''),
#   Text(1.0755403745466272, 0.23067922039078603, ''),
#   Text(1.0711210939394682, 0.2503988860157273, ''),
#   Text(1.068775785152732, 0.26022744104179596, ''),
#   Text(1.0663402920342686, 0.27003403782536556, ''),
#   Text(1.0638148200933366, 0.27981784887633987, ''),
#   Text(1.0638148200933366, 0.27981784887633987, ''),
#   Text(1.0611995824316944, 0.2895780486273045, ''),
#   Text(1.0584947997256189, 0.2993138135031895, ''),
#   Text(1.0584947997256189, 0.2993138135031895, ''),
#   Text(1.0557007002072838, 0.30902432199076313, ''),
#   Text(1.0498455013258297, 0.32836629447298227, ''),
#   Text(1.0467848960300405, 0.33799612637333176, ''),
#   Text(1.0467848960300405, 0.33799612637333176, ''),
#   Text(1.0467848960300405, 0.33799612637333176, ''),
#   Text(1.0436359620149613, 0.3475974378344957, ''),
#   Text(1.0403989649906822, 0.3571694186885514, ''),
#   Text(1.0403989649906822, 0.3571694186885514, ''),
#   Text(1.0370741780981338, 0.3667112612425207, ''),
#   Text(1.0336618818860421, 0.3762221603465248, ''),
#   Text(1.0336618818860421, 0.3762221603465248, ''),
#   Text(1.0336618818860421, 0.3762221603465248, ''),
#   Text(1.0301623642872526, 0.3857013134617226, ''),
#   Text(1.0229028534351714, 0.40456118503161453, ''),
#   Text(1.0191434727464084, 0.41394031207215276, ''),
#   Text(1.0191434727464084, 0.41394031207215276, ''),
#   Text(1.0152980957483155, 0.423284510429858, ''),
#   Text(1.0113670469175138, 0.43259299163225895, ''),
#   Text(1.0113670469175138, 0.43259299163225895, ''),
#   Text(1.0113670469175138, 0.43259299163225895, ''),
#   Text(1.0113670469175138, 0.43259299163225895, ''),
#   Text(1.0073506579596954, 0.44186497022073273, ''),
#   Text(0.9990632224625919, 0.46029629318805254, ''),
#   Text(0.9947928752251085, 0.46945408231408725, ''),
#   Text(0.9904385864052039, 0.4785722584518055, ''),
#   Text(0.9814796607465629, 0.4966866975678048, ''),
#   Text(0.9768757798706157, 0.5056814320322396, ''),
#   Text(0.9721894692740368, 0.5146334966096425, ''),
#   Text(0.9674211243922347, 0.5235421359161692, ''),
#   Text(0.9674211243922347, 0.5235421359161692, ''),
#   Text(0.9625711475827503, 0.5324065982322415, ''),
#   Text(0.9576399480913053, 0.541226135565978, ''),
#   Text(0.9576399480913053, 0.541226135565978, ''),
#   Text(0.9576399480913053, 0.541226135565978, ''),
#   Text(0.9526279420172694, 0.550000003716311, ''),
#   Text(0.9423632085759056, 0.5674077749930154, ''),
#   Text(0.9371113473566872, 0.5760402092348542, ''),
#   Text(0.9317804117780105, 0.5846240366481704, ''),
#   Text(0.9263708516693623, 0.5931585329213268, ''),
#   Text(0.9263708516693623, 0.5931585329213268, ''),
#   Text(0.9263708516693623, 0.5931585329213268, ''),
#   Text(0.9263708516693623, 0.5931585329213268, ''),
#   Text(0.9263708516693623, 0.5931585329213268, ''),
#   Text(0.9208831234946423, 0.6016429779052953, ''),
#   Text(0.9153176903136478, 0.6100766556744235, ''),
#   Text(0.9153176903136478, 0.6100766556744235, ''),
#   Text(0.9153176903136478, 0.6100766556744235, ''),
#   Text(0.9096750217429995, 0.618458854586846, ''),
#   Text(0.8981598894450288, 0.6350659910529722, ''),
#   Text(0.8922883973756779, 0.643289527280481, ''),
#   Text(0.8863416131506257, 0.6514587821171396, ''),
#   Text(0.8742241817258581, 0.6676316949379755, ''),
#   Text(0.8680545570066952, 0.675633988236168, ''),
#   Text(0.8618116850066582, 0.6835792708866945, ''),
#   Text(0.849108312418434, 0.6992961273894768, ''),
#   Text(0.8426488837530798, 0.7070663750382201, ''),
#   Text(0.8426488837530798, 0.7070663750382201, ''),
#   Text(0.8361183515620677, 0.7147769597441784, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8295172668980038, 0.7224272308807761, ''),
#   Text(0.8228461867667795, 0.7300165429107551, ''),
#   Text(0.809296297610342, 0.7450097332748028, ''),
#   Text(0.8024186319378469, 0.7524123464690052, ''),
#   Text(0.8024186319378469, 0.7524123464690052, ''),
#   Text(0.8024186319378469, 0.7524123464690052, ''),
#   Text(0.8024186319378469, 0.7524123464690052, ''),
#   Text(0.8024186319378469, 0.7524123464690052, ''),
#   Text(0.8024186319378469, 0.7524123464690052, ''),
#   Text(0.8024186319378469, 0.7524123464690052, ''),
#   Text(0.7954732574071495, 0.7597514703836111, ''),
#   Text(0.7813817316646453, 0.7742367786541534, ''),
#   Text(0.7742367695093737, 0.781381740725805, ''),
#   Text(0.767026476508637, 0.7884607690524277, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
#   Text(0.7597514610739133, 0.7954732662987827, ''),
# ...
#   Text(-0.4510996285926656, -1.0032492836197588, ''),
#   Text(-0.44186493485261663, -1.0073506734735889, ''),
#   Text(-0.44186493485261663, -1.0073506734735889, ''),
#   Text(-0.44186493485261663, -1.0073506734735889, ''),
#   Text(-0.44186493485261663, -1.0073506734735889, ''),
#   Text(-0.43259295612312737, -1.011367062105868, ''),
#   Text(-0.4232844747827071, -1.0152981106098484, ''),
#   Text(-0.4232844747827071, -1.0152981106098484, ''),
#   Text(-0.4139402762899906, -1.019143487279866, ''),
#   Text(-0.39514788468491474, -1.0265759344680927, ''),
#   Text(-0.3857012772926869, -1.0301623778292381, ''),
#   Text(-0.3857012772926869, -1.0301623778292381, ''),
#   Text(-0.3857012772926869, -1.0301623778292381, ''),
#   Text(-0.3762221240546209, -1.0336618950952143, ''),
#   Text(-0.3667112248308111, -1.037074190973378, ''),
#   Text(-0.3667112248308111, -1.037074190973378, ''),
#   Text(-0.35716938216010835, -1.0403989775309117, ''),
#   Text(-0.3379960896206785, -1.0467849078970954, ''),
#   Text(-0.3187087177434935, -1.0528175308353762, ''),
#   Text(-0.30902428492507583, -1.0557007110571375, ''),
#   Text(-0.30902428492507583, -1.0557007110571375, ''),
#   Text(-0.29931377633940126, -1.0584948102345362, ''),
#   Text(-0.2895780113685513, -1.061199592598789, ''),
#   Text(-0.2895780113685513, -1.061199592598789, ''),
#   Text(-0.2798178115257656, -1.06381482991775, ''),
#   Text(-0.27003400038612196, -1.066340301515172, ''),
#   Text(-0.27003400038612196, -1.066340301515172, ''),
#   Text(-0.2602274035170421, -1.0687757942893255, ''),
#   Text(-0.25039884840862964, -1.0711211027309808, ''),
#   Text(-0.25039884840862964, -1.0711211027309808, ''),
#   Text(-0.2405491644038455, -1.073376028940749, ''),
#   Text(-0.22078973592125836, -1.0776139812158254, ''),
#   Text(-0.21088165876309128, -1.0795966496786322, ''),
#   Text(-0.21088165876309128, -1.0795966496786322, ''),
#   Text(-0.21088165876309128, -1.0795966496786322, ''),
#   Text(-0.21088165876309128, -1.0795966496786322, ''),
#   Text(-0.20095578720713445, -1.081488220734725, ''),
#   Text(-0.19101295880800456, -1.083288534771513, ''),
#   Text(-0.19101295880800456, -1.083288534771513, ''),
#   Text(-0.18105401255115308, -1.0849974398767617, ''),
#   Text(-0.17107978878207192, -1.0866147918514093, ''),
#   Text(-0.16109112913538418, -1.0881404542217366, ''),
#   Text(-0.15108887646382618, -1.0895742982508805, ''),
#   Text(-0.15108887646382618, -1.0895742982508805, ''),
#   Text(-0.14107387476712596, -1.0909162029496993, ''),
#   Text(-0.13104696912078934, -1.0921660550869794, ''),
#   Text(-0.13104696912078934, -1.0921660550869794, ''),
#   Text(-0.13104696912078934, -1.0921660550869794, ''),
#   Text(-0.13104696912078934, -1.0921660550869794, ''),
#   Text(-0.13104696912078934, -1.0921660550869794, ''),
#   Text(-0.12100900560478614, -1.0933237491989922, ''),
#   Text(-0.11096083123216076, -1.0943891875983918, ''),
#   Text(-0.10090329387755956, -1.0953622803824583, ''),
#   Text(-0.08076352559969124, -1.097031108461701, ''),
#   Text(-0.06059649828008215, -1.0983296701793102, ''),
#   Text(-0.05050488927968716, -1.0988399593020117, ''),
#   Text(-0.04040901862801608, -1.0992575272489704, ''),
#   Text(-0.03030973822437331, -1.0995823387854, ''),
#   Text(-0.020207900255781407, -1.0998143665033897, ''),
#   Text(-0.01010435712507271, -1.099953590824217, ''),
#   Text(3.86210371883183e-08, -1.0999999999999994, ''),
#   Text(0.010104434363888208, -1.0999535901146857, ''),
#   Text(0.020207977484820533, -1.099814365084387, ''),
#   Text(0.030309815437119414, -1.0995823366570454, ''),
#   Text(0.030309815437119414, -1.0995823366570454, ''),
#   Text(0.030309815437119414, -1.0995823366570454, ''),
#   Text(0.030309815437119414, -1.0995823366570454, ''),
#   Text(0.030309815437119414, -1.0995823366570454, ''),
#   Text(0.030309815437119414, -1.0995823366570454, ''),
#   Text(0.04040909581795387, -1.0992575244114435, ''),
#   Text(0.05050496644030327, -1.0988399557555522, ''),
#   Text(0.05050496644030327, -1.0988399557555522, ''),
#   Text(0.05050496644030327, -1.0988399557555522, ''),
#   Text(0.060596575404865696, -1.0983296659242172, ''),
#   Text(0.07068307117194202, -1.0977266979761868, ''),
#   Text(0.07068307117194202, -1.0977266979761868, ''),
#   Text(0.07068307117194202, -1.0977266979761868, ''),
#   Text(0.07068307117194202, -1.0977266979761868, ''),
#   Text(0.08076360263328966, -1.097031102790478, ''),
#   Text(0.1009033707939727, -1.0953622732970194, ''),
#   Text(0.11096090808024324, -1.094389179806712, ''),
#   Text(0.11096090808024324, -1.094389179806712, ''),
#   Text(0.12100908237805344, -1.093323740701729, ''),
#   Text(0.13104704581276327, -1.0921660458848497, ''),
#   Text(0.13104704581276327, -1.0921660458848497, ''),
#   Text(0.13104704581276327, -1.0921660458848497, ''),
#   Text(0.14107395137133516, -1.0909161930434796, ''),
#   Text(0.15108895297380576, -1.089574287641407, ''),
#   Text(0.16109120554467907, -1.088140442909904, ''),
#   Text(0.17107986508423467, -1.0866147798381725, ''),
#   Text(0.18105408873974527, -1.0849974271631342, ''),
#   Text(0.1910130348765973, -1.0832885213585677, ''),
#   Text(0.1910130348765973, -1.0832885213585677, ''),
#   Text(0.1910130348765973, -1.0832885213585677, ''),
#   Text(0.1910130348765973, -1.0832885213585677, ''),
#   Text(0.1910130348765973, -1.0832885213585677, ''),
#   Text(0.1910130348765973, -1.0832885213585677, ''),
#   Text(0.1910130348765973, -1.0832885213585677, ''),
#   Text(0.200955863149309, -1.0814882066235934, ''),
#   Text(0.22078981159138347, -1.0776139657119528, ''),
#   Text(0.24054923977638223, -1.0733760120493678, ''),
#   Text(0.26022747856655, -1.068775776016137, ''),
#   Text(0.2700340752646094, -1.0663402825533637, ''),
#   Text(0.2700340752646094, -1.0663402825533637, ''),
#   Text(0.2700340752646094, -1.0663402825533637, ''),
#   Text(0.2700340752646094, -1.0663402825533637, ''),
#   Text(0.2798178862269142, -1.0638148102689218, ''),
#   Text(0.2895780858860577, -1.0611995722645988, ''),
#   Text(0.2895780858860577, -1.0611995722645988, ''),
#   Text(0.2993138506669777, -1.0584947892167, ''),
#   Text(0.31870879167241095, -1.052817508455626, ''),
#   Text(0.3283663313330932, -1.0498454897968774, ''),
#   Text(0.3283663313330932, -1.0498454897968774, ''),
#   Text(0.3283663313330932, -1.0498454897968774, ''),
#   Text(0.3283663313330932, -1.0498454897968774, ''),
#   Text(0.33799616312598474, -1.0467848841629845, ''),
#   Text(0.357169455216994, -1.040398952450451, ''),
#   Text(0.37622219663842815, -1.0336618686768686, ''),
#   Text(0.3951479567711454, -1.026575906720779, ''),
#   Text(0.41394034785431416, -1.0191434582129493, ''),
#   Text(0.423284546077008, -1.0152980808867815, ''),
#   Text(0.43259302714138975, -1.0113670317291588, ''),
#   Text(0.4418650055888479, -1.007350642445801, ''),
#   Text(0.4418650055888479, -1.007350642445801, ''),
#   Text(0.4418650055888479, -1.007350642445801, ''),
#   Text(0.45109969904089703, -1.0032492519435101, ''),
#   Text(0.46945411724129815, -0.9947928587425594, ''),
#   Text(0.47857229322613715, -0.9904385696025153, ''),
#   Text(0.47857229322613715, -0.9904385696025153, ''),
#   Text(0.4876500868192272, -0.9860007063005586, ''),
#   Text(0.4966867320275883, -0.9814796433078757, ''),
#   Text(0.4966867320275883, -0.9814796433078757, ''),
#   Text(0.4966867320275883, -0.9814796433078757, ''),
#   Text(0.5056814663303805, -0.9768757621161233, ''),
#   Text(0.5146335307432469, -0.9721894512052369, ''),
#   Text(0.5235421698823569, -0.9674211060106522, ''),
#   Text(0.5412261691887482, -0.957639929088837, ''),
#   Text(0.5500000371631095, -0.9526279227067503, ''),
#   Text(0.5500000371631095, -0.9526279227067503, ''),
#   Text(0.558727495603787, -0.9475355326616097, ''),
#   Text(0.5674078080794186, -0.9423631886541992, ''),
#   Text(0.5674078080794186, -0.9423631886541992, ''),
#   Text(0.5674078080794186, -0.9423631886541992, ''),
#   Text(0.5674078080794186, -0.9423631886541992, ''),
#   Text(0.5674078080794186, -0.9423631886541992, ''),
#   Text(0.5674078080794186, -0.9423631886541992, ''),
#   Text(0.5760402421368651, -0.9371113271318953, ''),
#   Text(0.5846240693630121, -0.9317803912518401, ''),
#   Text(0.5846240693630121, -0.9317803912518401, ''),
#   Text(0.5931585654462387, -0.9263708308435453, ''),
#   Text(0.6016430102375327, -0.9208831023709363, ''),
#   Text(0.6100766878112583, -0.9153176688938351, ''),
#   Text(0.6184588865255667, -0.9096750000288876, ''),
#   Text(0.6267888990824441, -0.9039555719099351, ''),
#   Text(0.635066022587396, -0.8981598671478398, ''),
#   Text(0.635066022587396, -0.8981598671478398, ''),
#   Text(0.6432895586087565, -0.8922883747897601, ''),
#   Text(0.6514588132366234, -0.8863415902778852, ''),
#   Text(0.6514588132366234, -0.8863415902778852, ''),
#   Text(0.6595730971414109, -0.8803200154076285, ''),
#   Text(0.6756340187135924, -0.8680545332851625, ''),
#   Text(0.6835793011449313, -0.8618116610061665, ''),
#   Text(0.6835793011449313, -0.8618116610061665, ''),
#   Text(0.6914669024954367, -0.8554960682278828, ''),
#   Text(0.7070664046236504, -0.8426488589279549, ''),
#   Text(0.7147769891003214, -0.836118326466224, ''),
#   Text(0.7147769891003214, -0.836118326466224, ''),
#   Text(0.7147769891003214, -0.836118326466224, ''),
#   Text(0.7224272600051549, -0.8295172415335589, ''),
#   Text(0.7300165718009121, -0.8228461611358735, ''),
#   Text(0.7300165718009121, -0.8228461611358735, ''),
#   Text(0.7375442840941429, -0.8161056481853672, ''),
#   Text(0.7524123746419498, -0.8024186055206236, ''),
#   Text(0.7597514983127034, -0.7954732307322493, ''),
#   Text(0.7670265134191482, -0.7884607331453263, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7742368060884918, -0.7813817044811654, ''),
#   Text(0.7813817679092835, -0.7742367420750341, ''),
#   Text(0.7884607959827525, -0.7670264488257524, ''),
#   Text(0.7884607959827525, -0.7670264488257524, ''),
#   Text(0.7954732929736815, -0.75975143314482, ''),
#   Text(0.8024186671608097, -0.7524123089050777, ''),
#   Text(0.8092963324867636, -0.7450096953889084, ''),
#   Text(0.8228462209413189, -0.7300165043905449, ''),
#   Text(0.8361183850231908, -0.7147769206026532, ''),
#   Text(0.8426489168532442, -0.7070663355909788, ''),
#   Text(0.8426489168532442, -0.7070663355909788, ''),
#   Text(0.8426489168532442, -0.7070663355909788, ''),
#   Text(0.8426489168532442, -0.7070663355909788, ''),
#   Text(0.8491083451548476, -0.699296087639847, ''),
#   Text(0.8554961248752083, -0.6914668324102772, ''),
#   Text(0.8618117170073126, -0.6835792305423768, ''),
#   Text(0.868054588635404, -0.6756339475996006, ''),
#   Text(0.868054588635404, -0.6756339475996006, ''),
#   Text(0.868054588635404, -0.6756339475996006, ''),
#   Text(0.868054588635404, -0.6756339475996006, ''),
#   Text(0.868054588635404, -0.6756339475996006, ''),
#   Text(0.868054588635404, -0.6756339475996006, ''),
#   Text(0.868054588635404, -0.6756339475996006, ''),
#   Text(0.8742242129799525, -0.6676316540125872, ''),
#   Text(0.8863416436476113, -0.6514587406244934, ''),
#   Text(0.892288427490233, -0.6432894855094458, ''),
#   Text(0.892288427490233, -0.6432894855094458, ''),
#   Text(0.892288427490233, -0.6432894855094458, ''),
#   Text(0.8981599191746126, -0.6350659490070726, ''),
#   Text(0.909675050695147, -0.6184588120018844, ''),
#   Text(0.9208831516595817, -0.6016429347956445, ''),
#   Text(0.9317804391462357, -0.5846239930283808, ''),
#   Text(0.9371113743230745, -0.5760401653655055, ''),
#   Text(0.9371113743230745, -0.5760401653655055, ''),
#   Text(0.9371113743230745, -0.5760401653655055, ''),
#   Text(0.9371113743230745, -0.5760401653655055, ''),
#   Text(0.9423632351381794, -0.5674077308778093, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9475355784344691, -0.5587274179784416, ''),
#   Text(0.9526279677646267, -0.5499999591205782, ''),
#   Text(0.9625711725065007, -0.5324065531710336, ''),
#   Text(0.9674211489010096, -0.5235420906279177, ''),
#   Text(0.9721894933657682, -0.5146334510981686, ''),
#   Text(0.9768758035432709, -0.5056813863013837, ''),
#   Text(0.9768758035432709, -0.5056813863013837, ''),
#   Text(0.9768758035432709, -0.5056813863013837, ''),
#   Text(0.981479683998144, -0.4966866516214257, ''),
#   Text(0.9904386088087869, -0.4785722120860289, ''),
#   Text(0.9990632440106153, -0.46029624641852773, ''),
#   Text(1.007350678644886, -0.4418649230632451, ''),
#   Text(1.0152981155636922, -0.423284462900324, ''),
#   Text(1.0191434921243514, -0.4139402643626037, ''),
#   Text(1.0191434921243514, -0.4139402643626037, ''),
#   Text(1.0191434921243514, -0.4139402643626037, ''),
#   Text(1.022902872374046, -0.4045611371460762, ''),
#   Text(1.026575939092644, -0.39514787267054347, ''),
#   Text(1.026575939092644, -0.39514787267054347, ''),
#   Text(1.0301623823432329, -0.38570126523634213, ''),
#   Text(1.037074195265126, -0.3667112126935741, ''),
#   Text(1.0403989817109882, -0.35716936998396026, ''),
#   Text(1.0403989817109882, -0.35716936998396026, ''),
#   Text(1.0436359782871707, -0.3475973889783699, ''),
#   Text(1.04678491185278, -0.3379960773697937, ''),
#   Text(1.04678491185278, -0.3379960773697937, ''),
#   Text(1.04678491185278, -0.3379960773697937, ''),
#   Text(1.04678491185278, -0.3379960773697937, ''),
#   Text(1.04678491185278, -0.3379960773697937, ''),
#   Text(1.04678491185278, -0.3379960773697937, ''),
#   Text(1.0498455166977643, -0.328366245326167, ''),
#   Text(1.0528175345653341, -0.3187087054220068, ''),
#   Text(1.0528175345653341, -0.3187087054220068, ''),
#   Text(1.0528175345653341, -0.3187087054220068, ''),
#   Text(1.0557007146737551, -0.30902427256984627, ''),
#   Text(1.0584948137375085, -0.2993137639514714, ''),
#   Text(1.06119959598782, -0.2895779989489664, ''),
#   Text(1.0663403046754731, -0.2700339879063736, ''),
#   Text(1.0711211056614849, -0.25039883587292994, ''),
#   Text(1.0755403853455, -0.2306791700411073, ''),
#   Text(1.0776139837998038, -0.22078972330957025, ''),
#   Text(1.0776139837998038, -0.22078972330957025, ''),
#   Text(1.0776139837998038, -0.22078972330957025, ''),
#   Text(1.079596652146653, -0.21088164612819932, ''),
#   Text(1.0814882230865797, -0.2009557745501048, ''),
#   Text(1.0814882230865797, -0.2009557745501048, ''),
#   Text(1.0832885370070036, -0.1910129461299052, ''),
#   Text(1.086614793853615, -0.17107977606504424, ''),
#   Text(1.0881404561070416, -0.1610911164005011, ''),
#   Text(1.0881404561070416, -0.1610911164005011, ''),
#   Text(1.0895743000191256, -0.15108886371216237, ''),
#   Text(1.0909162046007352, -0.14107386199975833, ''),
#   Text(1.092166056620667, -0.1310469563387943, ''),
#   Text(1.0933237506152023, -0.12100899280924218, ''),
#   Text(1.0933237506152023, -0.12100899280924218, ''),
#   Text(1.0943891888970045, -0.11096081842414761, ''),
#   Text(1.096242946503783, -0.09083722937597803, ''),
#   Text(1.097031109406904, -0.08076351276075878, ''),
#   Text(1.097031109406904, -0.08076351276075878, ''),
#   Text(1.097031109406904, -0.08076351276075878, ''),
#   Text(1.0977267037667815, -0.07068298124242564, ''),
#   Text(1.0988399598930878, -0.0505048764195851, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.0995823391401252, -0.03030972535558293, ''),
#   Text(1.0998143667398899, -0.020207887384275522, ''),
#   Text(1.0999535909424718, -0.010104344251936466, ''),
#   Text(1.0999999999999988, 5.149471657675648e-08, '')])

# %%
import seaborn as sns

# %%
keys = ['a', 'b', 'c']
values = [100, 200, 300]

# %%
d=dict(zip(keys,values))

# %%
import datetime
x=datetime.datetime.now()
x.year
# Out:
# 2024

# %%
sorted()

# %%
import datetime

x = datetime.datetime(2018, 6, 1)

print(x.strftime("%D"))
# Out:
# 06/01/18

# %%
from datetime import datetime,timedelta
x=datetime.now()
x.strftime("%d %m %Y")
my=datetime(2024,5,27)

# %%
my
# Out:
# datetime.datetime(2024, 5, 27, 0, 0)

# %%
x
# Out:
# datetime.datetime(2024, 1, 25, 8, 55, 3, 780389)

# %%
x.second*100
# Out:
# 300

# %%
date1 = datetime(2023,12,15)
date2 = datetime(2028,11,17)
d3=date1-date2
d3.seconds
# Out:
# 0
