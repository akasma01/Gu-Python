# %%
import pandas as pd

# %%
import pandas as pd

#df = pd.read_csv('customer.csv', encoding='utf-8')
df = pd.read_csv('customer.csv', encoding='latin-1')

# %%
df.shape
# Out:
# (18148, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG  04-08-1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES  08-12-1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON  08-08-1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG  07-04-1958             M
# 18144        29480   MRS.       NINA     RAJI  11-10-1960             S
# 18145        29481    MR.       IVAN     SURI  01-05-1960             S
# 18146        29482    MR.    CLAYTON    ZHANG  03-05-1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO  12-08-1959             M
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG  04-08-1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES  08-12-1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON  08-08-1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG  07-04-1958             M
# 18144        29480   MRS.       NINA     RAJI  11-10-1960             S
# 18145        29481    MR.       IVAN     SURI  01-05-1960             S
# 18146        29482    MR.    CLAYTON    ZHANG  03-05-1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO  12-08-1959             M
#
# ...

# %%
df.isnull().sum()
# Out:
# CustomerKey         0
# Prefix            130
# FirstName           0
# LastName            0
# BirthDate           0
# MaritalStatus       0
# Gender            130
# EmailAddress        0
# AnnualIncome        0
# TotalChildren       0
# EducationLevel      0
# Occupation          0
# HomeOwner           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.rename(columns={"FirstName":"Fname","LirstName":"Lname"},inplace=True)

# %%
df
# Out:
#        CustomerKey Prefix      Fname LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG  04-08-1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES  08-12-1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON  08-08-1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG  07-04-1958             M
# 18144        29480   MRS.       NINA     RAJI  11-10-1960             S
# 18145        29481    MR.       IVAN     SURI  01-05-1960             S
# 18146        29482    MR.    CLAYTON    ZHANG  03-05-1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO  12-08-1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Gender"].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df.shape
# Out:
# (18148, 13)

# %%
df.dropna()
# Out:
#        CustomerKey Prefix      Fname LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG  04-08-1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES  08-12-1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON  08-08-1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG  07-04-1958             M
# 18144        29480   MRS.       NINA     RAJI  11-10-1960             S
# 18145        29481    MR.       IVAN     SURI  01-05-1960             S
# 18146        29482    MR.    CLAYTON    ZHANG  03-05-1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO  12-08-1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
df.shape
# Out:
# (18148, 13)

# %%
df[["Gender"]][20:500]
# Out:
#     Gender
# 20       F
# 21       M
# 22       M
# 23       M
# 24     NaN
# ..     ...
# 495      F
# 496      F
# 497      M
# 498      M
# 499      F
#
# [480 rows x 1 columns]

# %%
df["Gender"].transform(lambda x:"Male" if x=="M" else x)
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3           F
# 4           F
#          ...
# 18143    Male
# 18144       F
# 18145    Male
# 18146    Male
# 18147    Male
# Name: Gender, Length: 18148, dtype: object

# %%
df
# Out:
#        CustomerKey Prefix      Fname LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG  04-08-1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES  08-12-1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON  08-08-1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG  07-04-1958             M
# 18144        29480   MRS.       NINA     RAJI  11-10-1960             S
# 18145        29481    MR.       IVAN     SURI  01-05-1960             S
# 18146        29482    MR.    CLAYTON    ZHANG  03-05-1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO  12-08-1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
df["Gender"].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df["Gender"].fillna("Other",inplace=True)

# %%
df
# Out:
#        CustomerKey Prefix      Fname LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG  04-08-1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES  08-12-1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON  08-08-1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG  07-04-1958             M
# 18144        29480   MRS.       NINA     RAJI  11-10-1960             S
# 18145        29481    MR.       IVAN     SURI  01-05-1960             S
# 18146        29482    MR.    CLAYTON    ZHANG  03-05-1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO  12-08-1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
df
# Out:
#        CustomerKey Prefix      Fname LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG  04-08-1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES  08-12-1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON  08-08-1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG  07-04-1958             M
# 18144        29480   MRS.       NINA     RAJI  11-10-1960             S
# 18145        29481    MR.       IVAN     SURI  01-05-1960             S
# 18146        29482    MR.    CLAYTON    ZHANG  03-05-1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO  12-08-1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %%
df.groupby(df["Occupation"])["TotalChildren"].count()
# Out:
# Occupation
# Clerical          2859
# Management        3011
# Manual            2353
# Professional      5424
# Skilled Manual    4501
# Name: TotalChildren, dtype: int64
